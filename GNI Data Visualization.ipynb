# %%
import pandas as pd

# %%
data=pd.read_csv('covid_19_india.csv')

# %%
data
# Out:
#          Sno       Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0          1  1/30/2020  6:00 PM               Kerala                       1
# 1          2  1/31/2020  6:00 PM               Kerala                       1
# 2          3   2/1/2020  6:00 PM               Kerala                       2
# 3          4   2/2/2020  6:00 PM               Kerala                       3
# 4          5   2/3/2020  6:00 PM               Kerala                       3
# ...      ...        ...      ...                  ...                     ...
# 18105  18106  8/11/2021  8:00 AM            Telangana                       -
# 18106  18107  8/11/2021  8:00 AM              Tripura                       -
# 18107  18108  8/11/2021  8:00 AM          Uttarakhand                       -
# 18108  18109  8/11/2021  8:00 AM        Uttar Pradesh                       -
# 18109  18110  8/11/2021  8:00 AM          West Bengal                       -
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18110 entries, 0 to 18109
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       18110 non-null  int64
#  1   Date                      18110 non-null  object
#  2   Time                      18110 non-null  object
#  3   State/UnionTerritory      18110 non-null  object
#  4   ConfirmedIndianNational   18110 non-null  object
#  5   ConfirmedForeignNational  18110 non-null  object
#  6   Cured                     18110 non-null  int64
#  7   Deaths                    18110 non-null  int64
#  8   Confirmed                 18110 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 1.2+ MB

# %%
data.nunique()
# Out:
# Sno                         18110
# Date                          560
# Time                            7
# State/UnionTerritory           46
# ConfirmedIndianNational        62
# ConfirmedForeignNational       12
# Cured                       14445
# Deaths                       6471
# Confirmed                   14971
# dtype: int64

# %%
# Plotting total cases over time (assuming the dataset has relevant columns)
data['Date'] = pd.to_datetime(data['Date'])  # Ensure 'Date' column is in datetime format

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18110 entries, 0 to 18109
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       18110 non-null  int64
#  1   Date                      18110 non-null  datetime64[ns]
#  2   Time                      18110 non-null  object
#  3   State/UnionTerritory      18110 non-null  object
#  4   ConfirmedIndianNational   18110 non-null  object
#  5   ConfirmedForeignNational  18110 non-null  object
#  6   Cured                     18110 non-null  int64
#  7   Deaths                    18110 non-null  int64
#  8   Confirmed                 18110 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 1.2+ MB

# %% [markdown]
# # Pandas Visualizations

# %%
data.columns
# Out:
# Index(['Sno', 'Date', 'Time', 'State/UnionTerritory',
#        'ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed'],
#       dtype='object')

# %%
data['ConfirmedForeignNational'].unique()
# Out:
# array(['0', '1', '2', '14', '3', '9', '7', '11', '10', '8', '6', '-'],
#       dtype=object)

# %%
val=['-']
data1=data[~data['ConfirmedForeignNational'].isin(val)]
data1['ConfirmedForeignNational'].unique()
# Out:
# array(['0', '1', '2', '14', '3', '9', '7', '11', '10', '8', '6'],
#       dtype=object)

# %%
data1['ConfirmedForeignNational'].value_counts().plot.bar(color=['g','m','b','y'])
# Out:
# <AxesSubplot:xlabel='ConfirmedForeignNational'>

# %%
data['ConfirmedForeignNational'].value_counts().plot.bar(title='ConfirmedForeignNational Distribution');

# %%
data['ConfirmedForeignNational'].value_counts(normalize=True).plot.bar(title='ConfirmedForeignNational Distribution', color=['m','blue']);

# %%
data['ConfirmedForeignNational'].unique()
# Out:
# array(['0', '1', '2', '14', '3', '9', '11', '7', '10', '8', '6', '-'],
#       dtype=object)

# %%
# Drop rows with specific values in the 'ConfirmedForeignNational' column
values_to_drop = [ '-']
data1 = data[~data['ConfirmedForeignNational'].isin(values_to_drop)]
data1['ConfirmedForeignNational'].value_counts(normalize=True).plot.bar(title='ConfirmedForeignNational Distribution');

# %%
data = data.sort_values(by='Date')
# Sort data by date
data
# Out:
#          Sno       Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0          1 2020-01-30  6:00 PM               Kerala                       1
# 1          2 2020-01-31  6:00 PM               Kerala                       1
# 2          3 2020-02-01  6:00 PM               Kerala                       2
# 3          4 2020-02-02  6:00 PM               Kerala                       3
# 4          5 2020-02-03  6:00 PM               Kerala                       3
# ...      ...        ...      ...                  ...                     ...
# 18105  18106 2021-08-11  8:00 AM            Telangana                       -
# 18106  18107 2021-08-11  8:00 AM              Tripura                       -
# 18092  18093 2021-08-11  8:00 AM          Lakshadweep                       -
# 18091  18092 2021-08-11  8:00 AM               Ladakh                       -
# 18109  18110 2021-08-11  8:00 AM          West Bengal                       -
#
# ...

# %%
data.groupby('Date')['Deaths'].sum().plot(title='Covid1 Deaths over time');

# %%
data
# Out:
#          Sno       Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0          1 2020-01-30  6:00 PM               Kerala                       1
# 1          2 2020-01-31  6:00 PM               Kerala                       1
# 2          3 2020-02-01  6:00 PM               Kerala                       2
# 3          4 2020-02-02  6:00 PM               Kerala                       3
# 4          5 2020-02-03  6:00 PM               Kerala                       3
# ...      ...        ...      ...                  ...                     ...
# 18105  18106 2021-08-11  8:00 AM            Telangana                       -
# 18106  18107 2021-08-11  8:00 AM              Tripura                       -
# 18092  18093 2021-08-11  8:00 AM          Lakshadweep                       -
# 18091  18092 2021-08-11  8:00 AM               Ladakh                       -
# 18109  18110 2021-08-11  8:00 AM          West Bengal                       -
#
# ...

# %%
data['Confirmed'].mean()
# Out:
# 301031.40182219766

# %%
data['Confirmed'].hist();

# %%
data.groupby('Date')['Confirmed'].sum().plot(kind='line', title='Confirmed Cases Over Time', figsize=(10, 6))
# Out:
# <AxesSubplot:title={'center':'Confirmed Cases Over Time'}, xlabel='Date'>

# %%
import matplotlib.pyplot as plt


# Line plot for daily confirmed cases
data.groupby('Date')['Confirmed'].sum().plot(
    kind='line', title='Daily Confirmed Cases Over Time', figsize=(10, 6))
plt.ylabel('Confirmed Cases')
plt.xlabel('Date')
plt.show()

# %%
data.columns
# Out:
# Index(['Sno', 'Date', 'Time', 'State/UnionTerritory',
#        'ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed'],
#       dtype='object')

# %%
# Bar plot for total cases by state
data.groupby('State/UnionTerritory')['Deaths'].sum().sort_values(ascending=False).tail(10).plot(kind='bar');

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
data.groupby('State/UnionTerritory')['Deaths'].sum().sort_values(ascending=False).head(10).plot(kind='bar', color=['r','b']);
plt.title('Top States with Reported Cases of Deaths')
plt.ylabel('Number of Deaths')
plt.xlabel('State Territory')
plt.show();

# %%
# Histogram of confirmed cases
plt.figure(figsize=(8, 5))
plt.hist(data['Confirmed'], bins=30, color='blue', edgecolor='black')
plt.title('Distribution of Confirmed Cases')
plt.xlabel('Confirmed Cases')
plt.ylabel('Frequency')
plt.show()

# %%
data.columns
# Out:
# Index(['Sno', 'Date', 'Time', 'State/UnionTerritory',
#        'ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed'],
#       dtype='object')

# %%
# Scatter plot for active vs. recovered cases
plt.figure(figsize=(8, 5))
plt.scatter(data['Deaths'], data['Confirmed'])
plt.title('Confirmed vs. Deaths Cases')
plt.xlabel('Deaths')
plt.ylabel('Confirmed')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18110 entries, 0 to 18109
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       18110 non-null  int64
#  1   Date                      18110 non-null  datetime64[ns]
#  2   Time                      18110 non-null  object
#  3   State/UnionTerritory      18110 non-null  object
#  4   ConfirmedIndianNational   18110 non-null  object
#  5   ConfirmedForeignNational  18110 non-null  object
#  6   Cured                     18110 non-null  int64
#  7   Deaths                    18110 non-null  int64
#  8   Confirmed                 18110 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# Heatmap for correlation
plt.figure(figsize=(10, 6))
sns.heatmap(data[['Confirmed',  'Cured', 'Deaths']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Boxplot for confirmed cases by state
plt.figure(figsize=(15, 6))
sns.boxplot(x='State/UnionTerritory', y='Confirmed', data=data)
plt.xticks(rotation=90)
plt.title('Confirmed Cases by State/Union Territory')
plt.show()

# %%
# Pairplot for numerical variables
sns.pairplot(data[['Confirmed', 'Cured', 'Deaths']])
plt.show()

# %%
diab = pd.read_csv('diabetes_data.csv')
diab
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age       Outcome
# 0                       0.627   50      Diabetic
# ...

# %%
diab.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
sns.countplot(x='Outcome', data=diab)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
sns.countplot(x='Pregnancies',hue='Outcome', data=diab);

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Francis Yego\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\Francis Yego\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
data = pd.read_csv('HR_DATA.csv')
data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
data.nunique()
# Out:
# satisfaction_level        92
# last_evaluation           65
# number_project             6
# average_montly_hours     215
# time_spend_company         8
# Work_accident              2
# left                       2
# promotion_last_5years      2
# Department                10
# salary                     3
# dtype: int64

# %%
data.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
plt.figure(figsize=(4,4))
plt.scatter(data.satisfaction_level, data.average_montly_hours, color='m')

plt.xlabel('Satisfaction level')
plt.ylabel('average montly hours')

plt.title('Satisfaction level vs average montly hour');

# %%
plt.scatter(data.satisfaction_level, data.left);

# %%
plt.scatter(data['satisfaction_level'], data['average_montly_hours'], alpha=0.7, c='blue')
plt.title('Satisfaction Level vs. Average Monthly Hours')
plt.xlabel('Satisfaction Level')
plt.ylabel('Average Monthly Hours')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
sal=data.salary.value_counts(normalize=True)*100
sal
# Out:
# salary
# low       48.776585
# medium    42.976198
# high       8.247216
# Name: proportion, dtype: float64

# %%
salary_counts = data['salary'].value_counts()
explode=[0.01,0.01,0.0]
plt.pie(salary_counts, labels=salary_counts.index, autopct='%1.1f%%', explode=explode,startangle=90)
plt.title('Salary Distribution')
plt.show()

# %%
plt.hist(data['satisfaction_level'], bins=5, color='purple', edgecolor='black')
plt.title('Distribution of Satisfaction Levels')
plt.xlabel('Satisfaction Level')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %%
data.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.boxplot(x='left',y='average_montly_hours', data=data);
plt.title('average montly hours vs attrition rate');
# plt.xticks([ticks='No','Yes'])

# %%
sns.countplot(x='Department',hue='left', data=data)
plt.xticks(rotation=90);

# %%
data.nunique()
# Out:
# satisfaction_level        92
# last_evaluation           65
# number_project             6
# average_montly_hours     215
# time_spend_company         8
# Work_accident              2
# left                       2
# promotion_last_5years      2
# Department                10
# salary                     3
# dtype: int64

# %%
sns.barplot(x='left',y='satisfaction_level', data=data)
plt.title('Satisfiction level vs Attrition Rate')
plt;

# %%
sns.boxplot(x='salary', y='average_montly_hours', data=data)
plt.title('Average Monthly Hours by Salary Level')
plt.show()
# Out:
# C:\Users\Francis Yego\anaconda3\lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
sns.barplot(x='salary', y='satisfaction_level', data=data)
plt.title('Satisfaction Level by Salary')
plt.show()

# %%
sns.countplot(x='salary', data=data)
plt.title('Count of Employees by Salary Level')
plt.show()

# %%
sns.scatterplot(x='satisfaction_level', y='average_montly_hours', hue='salary', style='salary', data=data, palette='dark')
plt.title('Satisfaction Level vs. Average Monthly Hours')
plt.xlabel('Satisfaction Level')
plt.ylabel('Average Monthly Hours')
plt.show()

# %%
import numpy as np

# %%
data_num=data.select_dtypes(include=np.number)

# %%
cor_matrix=data_num.corr()
plt.figure(figsize=(10,10))
sns.heatmap(cor_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(x='salary', y='satisfaction_level', data=data, palette="muted", split=True)
plt.title('Satisfaction Level Distribution by Salary')
plt.xlabel('Salary')
plt.ylabel('Satisfaction Level')
plt.show()
# Out:
# C:\Users\Francis Yego\AppData\Local\Temp\ipykernel_31428\671933356.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='salary', y='satisfaction_level', data=data, palette="muted", split=True)
